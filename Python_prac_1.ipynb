# %%
print("Hello! My name is Akhilesh Jaguri and my hobby is playing table tennis and badminton, and coding cool projects")
# Out:
# Hello! My name is Akhilesh Jaguri and my hobby is playing table tennis and badminton, and coding cool projects

# %%
# this is a comment
print("comments do not affect the output")
# Out:
# comments do not affect the output

# %%
a = 10
b = 10.5
c = "Hello"
d = True

print(a, type(a))
print(b, type(b))
print(c, type(c))
print(d, type(d))
# Out:
# 10 <class 'int'>
# 10.5 <class 'float'>
# Hello <class 'str'>
# True <class 'bool'>

# %%
f = 9.8
print(int(f))

s = "25"
print(int(s))

bool_val = True
print(int(bool_val))
# Out:
# 9
# 25
# 1

# %%
num1 = 10
num2 = 5

print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
# Out:
# 15
# 5
# 50
# 2.0

# %%
minutes = 160
hours = minutes / 60
print(hours)
# Out:
# 2.6666666666666665
