# %%
shop_list = []

# %%
shop_list = ["watch", "laptop", "shoes", "pen", "clothes"]

# %%
shop_list.append("football")

# %%
print("Last Item:", shop_list[-1])
# Out:
# Last Item: football

# %%
print("Shopping list:", shop_list)
# Out:
# Shopping list: ['watch', 'laptop', 'shoes', 'pen', 'clothes', 'football']

# %%
print("Important items :", shop_list[1:3])
# Out:
# Important items : ['laptop', 'shoes']

# %%
shop_list[3] = "notebook"

# %%
shop_list.remove("clothes")

# %%
print("Final Shopping list:", shop_list)
# Out:
# Final Shopping list: ['watch', 'laptop', 'shoes', 'notebook', 'football']
