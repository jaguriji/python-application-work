# %%
inventory = {}
type(inventory)
# Out:
# dict

# %%
ProductNo1 = {
    "name": "Mobile Phone",
    "quantity": 5,
    "price": 20000,
    "releaseYear": 2020
}

# %%
inventory["ProductNo1"] = ProductNo1

# %%
ProductNo2 = {
    "name": "Laptop",
    "quantity": 3,
    "price": 55000,
    "releaseYear": 2021
}

# %%
inventory["ProductNo2"] = ProductNo2

# %%
print("Inventory:")
for product, details in inventory.items():
    print(product, ":", details)
# Out:
# Inventory:
# ProductNo1 : {'name': 'Mobile Phone', 'quantity': 5, 'price': 20000, 'releaseYear': 2020}
# ProductNo2 : {'name': 'Laptop', 'quantity': 3, 'price': 55000, 'releaseYear': 2021}

# %%
print("Is releaseYear in ProductNo1?", "releaseYear" in inventory["ProductNo1"])
print("Is releaseYear in ProductNo2?", "releaseYear" in inventory["ProductNo2"])
# Out:
# Is releaseYear in ProductNo1? True
# Is releaseYear in ProductNo2? True

# %%
del inventory["ProductNo1"]["releaseYear"]
del inventory["ProductNo2"]["releaseYear"]

# %%
print("Inventory after deleting release years:")
for product, details in inventory.items():
    print(product, ":", details)
# Out:
# Inventory after deleting release years:
# ProductNo1 : {'name': 'Mobile Phone', 'quantity': 5, 'price': 20000}
# ProductNo2 : {'name': 'Laptop', 'quantity': 3, 'price': 55000}

# %%
prices = (250, 300, 150, 400, 100, 350, 200)

# %%
print("Highest price:", max(prices))
print("Lowest price:", min(prices))
print("Total sum of prices:", sum(prices))
# Out:
# Highest price: 400
# Lowest price: 100
# Total sum of prices: 1750

# %%
sorted_prices = sorted(prices)
print(type(sorted_prices))
print("Sorted prices (list):", sorted_prices)
# Out:
# <class 'list'>
# Sorted prices (list): [100, 150, 200, 250, 300, 350, 400]

# %%
try:
    prices[0] = 500
except TypeError as err:
    print("Error while modifying tuple:", err)
    print("Explanation: Tuples are immutable, so their elements cannot be changed after creation.")
# Out:
# Error while modifying tuple: 'tuple' object does not support item assignment
# Explanation: Tuples are immutable, so their elements cannot be changed after creation.
